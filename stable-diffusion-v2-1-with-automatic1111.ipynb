# %% [markdown]
# **Stable Diffusion version 2.1 with Automatic1111**
#
# This notebook has v2-1_768-ema-pruned.ckpt as the default model. If you want to use v2-1_512-ema-pruned.ckpt, uncomment the two line for the 512 model and comment out the two lines for 768 model. If you have both models loaded, the notebook might run out of memory. If you see a read error when downloading the DiffusionWrapper, please try again later when the network is not that congested.
#
# * Added code to rerun Automatic1111 afer read timeout error. (12/9/2022)

# %% [markdown]
# !pip install torch==1.12.1+cu113 torchvision==0.13.1+cu113 --extra-index-url https://download.pytorch.org/whl/cu113
# !pip install transformers==4.19.2 diffusers invisible-watermark
#
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui.git
# %cd /kaggle/working/stable-diffusion-webui
# #Use a version committed on 12/23/2022, because newer version might not work
# !git checkout 0c747d4013f41f6c887a63d256af884aa8872f91
#
# !sed -i -e 's/numpy==1.23.3/numpy==1.21.6/g' requirements_versions.txt
# !sed -i -e 's/fairscale==0.4.9/fairscale==0.4.6/g' requirements_versions.txt
#
#
# #Comment the following two lines if you want to use the 512 model
# !wget -O /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/v2-1_768-ema-pruned.ckpt -L https://huggingface.co/stabilityai/stable-diffusion-2-1/resolve/main/v2-1_768-ema-pruned.ckpt
# !wget -O /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/v2-1_768-ema-pruned.yaml -L https://raw.githubusercontent.com/Stability-AI/stablediffusion/main/configs/stable-diffusion/v2-inference-v.yaml
# !wget -O /kaggle/working/stable-diffusion-webui/models/lyriel_v13.safetensors https://apps.easierit.org/model/lyriel_v13.safetensors
#
# #Uncomment the following two lines for 512-base-ema.ckpt support
# #!wget -O /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/v2-1_512-ema-pruned.ckpt -L https://huggingface.co/stabilityai/stable-diffusion-2-1-base/resolve/main/v2-1_512-ema-pruned.ckpt
# #!cp /kaggle/input/stable-diffusion-v20-config-files/512-base-ema.yaml /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/v2-1_512-ema-pruned.yaml
#
#
# !python launch.py --share --no-half

# %%
# After you are done with generating the pictures, cancel Run.
# Zip images to output.zip. You can then download it at Data -> Output
# !zip -q -r output.zip /kaggle/working/stable-diffusion-webui/outputs 
# !mv /kaggle/working/stable-diffusion-webui/output.zip /kaggle/working/output.zip

# %%
#Run this if you had read timeout error.
# %cd /kaggle/working/stable-diffusion-webui

# !python launch.py --share --no-half
